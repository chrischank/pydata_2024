# %% [markdown]
# # Causality - Mental Hygiene for Data Science
# Harness teh power of why with causal tools\
#
# - Applicable or not, causality is good for mental hygiene
# - Causal Graphs - visual aids to articulate understanding of the mecahnism of a system
#
# ### The allure and reality of causality
# - Real world decision require accountability
# - Accountability requires understanding
# - Standard ML are amazing but do not truly understand
# - They capture patterns not mechanism.
# - Association based decision can backfire due to misinterpretation
#
# Shifting from "what happened?" (passive) to "what would happen if" (active)\
#
# ### Randomised Control Trials
# Advantages
# - Eliminates confounding factors
# Disadvantages
# - Expensive to recruit
# - Feasibility - intervention might not be physically possible or ethical to conduct
# - Artificial setting of a lab
# - Not individualised
#
# ### The seductive promise of causality
# - Beyond correlation
#
# ### Hard Truth about causality
# - Requires strong assumption about the world
# - Some Causal questions
#
# Causual inference:
# - Is not a standard tool
# - Frame of mind
# - Maybe useful to enhance interpretation
#
# ## Case Study
# ### A ML Paradox
# >Causation is not merely an aspect of statistics, it is an addition to statistics
#
# ## Causal Graphs - Visualise the story behind the data
# Graphs visualise the qualitative relationship between the parameters
#
# ### DAG
# Properties
# - Articulates the practitioner's understanding of the underlying mechanism
# - Non cyclic paths
# - Encodes of joint condition in/dependence relationships
# - Maybe tested
#
# Utility
# - Causal interpretation of data
# - Design better experiments
# - Knowledge transferability between experts/experiments
#
# ## Building DAG
# What is required
# - Domain expertise
#     - Speaking with experts
#     - Scanning literatures
# - Testing assumptions
#     - Requires reliable empirical data
#
# ### Manual Causal Discovery
# We start by stating clear statement
# - Drownings are correlated with ice creams sales
# - But Drawnings are noit caused by ice cream sales
# - Ice cream sales
#
# ### Spectrum of DAG Building Complexity
# Depends on domain expertise and controls of the data generation process
# - Full control: over the data generation process: Synthetic / Simulated data
# - Partial control: RCTs, A/B tests
# - No control: Full observational - no true understanding directionality
#
# ### DAGs as Visual Mental Hygiene
#
# ### Assessing Applicability with Idenfiability
# - A framework to assess minimal sets of parameters required to quantify a specific causal effect
# - Helps assess parameters as sufficient / necessary
# - Posssible benefit: Less data -> more pearameters
#
# > If you can't measure and articulate it you can't fix it
#
# ## Assessing applicability is valuable in its own right,.
# ## Brings scientific rigour - by articulating the data generation process:
# - Documentation and quantification of domain expertise
#
# - Applicable or not, causality is good for mental hygiene
# - DAG help articulate understanding of a system by visualising it
# - Identifiability is a framework to assess the ability to answer specific questions.
